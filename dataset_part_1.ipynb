# %%
import os

base_dir = r"MIMIC -III (10000 patients)"
import pandas as pd

admissions_csv = os.path.join(base_dir, "ADMISSIONS\ADMISSIONS_random.csv")
admissions_df = pd.read_csv(admissions_csv)

admissions_df.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0      22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 1      23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 2      26          26   197661  2126-05-06 15:16:00  2126-05-13 15:00:00
# 3      29          30   104557  2172-10-14 14:17:00  2172-10-19 14:37:00
# 4      33          34   115799  2186-07-18 16:46:00  2186-07-20 16:00:00
#
#   DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION DISCHARGE_LOCATION  \
# 0       NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI   HOME HEALTH CARE
# 1       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM   HOME HEALTH CARE
# 2       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM               HOME
# 3       NaN         URGENT  TRANSFER FROM HOSP/EXTRAM   HOME HEALTH CARE
# 4       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM               HOME
#
#   INSURANCE LANGUAGE  RELIGION MARITAL_STATUS              ETHNICITY  \
# ...

# %%
admissions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12537 entries, 0 to 12536
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ROW_ID                12537 non-null  int64
#  1   SUBJECT_ID            12537 non-null  int64
#  2   HADM_ID               12537 non-null  int64
#  3   ADMITTIME             12537 non-null  object
#  4   DISCHTIME             12537 non-null  object
#  5   DEATHTIME             1225 non-null   object
#  6   ADMISSION_TYPE        12537 non-null  object
#  7   ADMISSION_LOCATION    12537 non-null  object
#  8   DISCHARGE_LOCATION    12537 non-null  object
#  9   INSURANCE             12537 non-null  object
#  10  LANGUAGE              7200 non-null   object
#  11  RELIGION              12432 non-null  object
#  12  MARITAL_STATUS        10351 non-null  object
#  13  ETHNICITY             12537 non-null  object
#  14  EDREGTIME             6579 non-null   object
# ...

# %%
admissions_df.describe()
# Out:
#              ROW_ID    SUBJECT_ID        HADM_ID  HOSPITAL_EXPIRE_FLAG  \
# count  12537.000000  12537.000000   12537.000000          12537.000000
# mean   29640.295844  34105.381271  149817.199250              0.097711
# std    17168.685188  28417.116052   28753.183887              0.296935
# min        1.000000      2.000000  100016.000000              0.000000
# 25%    14883.000000  12108.000000  125108.000000              0.000000
# 50%    29840.000000  24442.000000  149842.000000              0.000000
# 75%    44503.000000  54708.000000  174440.000000              0.000000
# max    58971.000000  99983.000000  199995.000000              1.000000
#
#        HAS_CHARTEVENTS_DATA
# count          12537.000000
# mean               0.974795
# std                0.156755
# min                0.000000
# 25%                1.000000
# 50%                1.000000
# 75%                1.000000
# max                1.000000

# %%
print(admissions_df.isna().sum())
# Out:
# ROW_ID                      0
# SUBJECT_ID                  0
# HADM_ID                     0
# ADMITTIME                   0
# DISCHTIME                   0
# DEATHTIME               11312
# ADMISSION_TYPE              0
# ADMISSION_LOCATION          0
# DISCHARGE_LOCATION          0
# INSURANCE                   0
# LANGUAGE                 5337
# RELIGION                  105
# MARITAL_STATUS           2186
# ETHNICITY                   0
# EDREGTIME                5958
# EDOUTTIME                5958
# DIAGNOSIS                   2
# HOSPITAL_EXPIRE_FLAG        0
# HAS_CHARTEVENTS_DATA        0
# dtype: int64

# %%
# DATETIMEEVENTS_CV_random.csv
datetimesevents_csv = os.path.join(base_dir, "DATETIMEEVENTS", "DATETIMEEVENTS_CV_random.csv")
datetimesevents_df = pd.read_csv(datetimesevents_csv)
datetimesevents_df.head()
# Out:
# C:\Users\fsultana\AppData\Local\Temp\ipykernel_20008\3654509949.py:3: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   datetimesevents_df = pd.read_csv(datetimesevents_csv)
#    ROW_ID  SUBJECT_ID   HADM_ID  ICUSTAY_ID  ITEMID            CHARTTIME  \
# 0     799       11022  102158.0    214338.0    3411  2188-03-30 05:00:00
# 1     800       11022  102158.0    214338.0    3411  2188-03-30 07:00:00
# 2     801       11022  102158.0    214338.0    3411  2188-03-30 08:00:00
# 3     802       11022  102158.0    214338.0    3411  2188-03-30 09:00:00
# 4     803       11022  102158.0    214338.0    3411  2188-03-30 10:00:00
#
#              STORETIME   CGID                VALUE VALUEUOM  WARNING  ERROR  \
# 0  2188-03-30 04:51:00  15917  2188-04-04 00:00:00     Date      NaN    NaN
# 1  2188-03-30 07:48:00  16975  2188-04-04 00:00:00     Date      NaN    NaN
# ...

# %%
datetimesevents_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517314 entries, 0 to 1517313
# Data columns (total 14 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   ROW_ID        1517314 non-null  int64
#  1   SUBJECT_ID    1517314 non-null  int64
#  2   HADM_ID       1517000 non-null  float64
#  3   ICUSTAY_ID    1516201 non-null  float64
#  4   ITEMID        1517314 non-null  int64
#  5   CHARTTIME     1517314 non-null  object
#  6   STORETIME     1517314 non-null  object
#  7   CGID          1517314 non-null  int64
#  8   VALUE         1499688 non-null  object
#  9   VALUEUOM      1517314 non-null  object
#  10  WARNING       911033 non-null   float64
#  11  ERROR         911033 non-null   float64
#  12  RESULTSTATUS  0 non-null        float64
#  13  STOPPED       606281 non-null   object
# dtypes: float64(5), int64(4), object(5)
# memory usage: 162.1+ MB

# %%
datetimesevents_df.describe()
# Out:
#              ROW_ID    SUBJECT_ID       HADM_ID    ICUSTAY_ID        ITEMID  \
# count  1.517314e+06  1.517314e+06  1.517000e+06  1.516201e+06  1.517314e+06
# mean   2.241904e+06  4.473322e+04  1.510787e+05  2.497471e+05  1.374645e+05
# std    1.291406e+06  2.944502e+04  2.856463e+04  2.884557e+04  1.072553e+05
# min    5.100000e+01  1.700000e+01  1.000030e+05  2.000030e+05  3.411000e+03
# 25%    1.127199e+06  1.918500e+04  1.266350e+05  2.251250e+05  6.704000e+03
# 50%    2.225698e+06  4.140300e+04  1.520700e+05  2.506280e+05  2.242620e+05
# 75%    3.379238e+06  7.051600e+04  1.757340e+05  2.746880e+05  2.242900e+05
# max    4.485937e+06  9.999900e+04  1.999990e+05  2.999860e+05  2.282910e+05
#
#                CGID        WARNING          ERROR  RESULTSTATUS
# count  1.517314e+06  911033.000000  911033.000000           0.0
# mean   1.757830e+04       0.000070       0.000262           NaN
# std    2.204864e+03       0.008381       0.016195           NaN
# ...

# %%
print(datetimesevents_df.isna().sum())
# Out:
# ROW_ID                0
# SUBJECT_ID            0
# HADM_ID             314
# ICUSTAY_ID         1113
# ITEMID                0
# CHARTTIME             0
# STORETIME             0
# CGID                  0
# VALUE             17626
# VALUEUOM              0
# WARNING          606281
# ERROR            606281
# RESULTSTATUS    1517314
# STOPPED          911033
# dtype: int64

# %%
# ICUSTAYS_random.csv
icustays_csv = os.path.join(base_dir, "ICUSTAYS", "ICUSTAYS_random.csv")
icustays_df = pd.read_csv(icustays_csv)
icustays_df.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID DBSOURCE FIRST_CAREUNIT  \
# 0     366         269   106296      206613  carevue           MICU
# 1     369         272   164716      210407  carevue            CCU
# 2     372         275   129886      219649  carevue            CCU
# 3     376         280   123506      247496  carevue           NICU
# 4     378         282   119013      293262  carevue          TSICU
#
#   LAST_CAREUNIT  FIRST_WARDID  LAST_WARDID               INTIME  \
# 0          MICU            52           52  2170-11-05 11:05:29
# 1           CCU            57           57  2186-12-25 21:08:04
# 2           CCU             7            7  2170-10-07 11:28:53
# 3          NICU            56           56  2155-12-08 18:22:09
# 4         TSICU            14           14  2175-02-02 17:01:10
#
#                OUTTIME      LOS
# 0  2170-11-08 17:46:57   3.2788
# 1  2186-12-27 12:01:13   1.6202
# 2  2170-10-14 14:38:07   7.1314
# 3  2155-12-22 17:10:45  13.9504
# ...

# %%
icustays_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13485 entries, 0 to 13484
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ROW_ID          13485 non-null  int64
#  1   SUBJECT_ID      13485 non-null  int64
#  2   HADM_ID         13485 non-null  int64
#  3   ICUSTAY_ID      13485 non-null  int64
#  4   DBSOURCE        13485 non-null  object
#  5   FIRST_CAREUNIT  13485 non-null  object
#  6   LAST_CAREUNIT   13485 non-null  object
#  7   FIRST_WARDID    13485 non-null  int64
#  8   LAST_WARDID     13485 non-null  int64
#  9   INTIME          13485 non-null  object
#  10  OUTTIME         13483 non-null  object
#  11  LOS             13483 non-null  float64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 1.2+ MB

# %%
icustays_df.describe()
# Out:
#              ROW_ID    SUBJECT_ID        HADM_ID     ICUSTAY_ID  FIRST_WARDID  \
# count  13485.000000  13485.000000   13485.000000   13485.000000  13485.000000
# mean   30816.053986  34119.623508  150051.275491  250023.571746     32.883352
# std    17902.164119  28420.292206   28911.812557   28676.064085     19.056796
# min        2.000000      3.000000  100010.000000  200010.000000      7.000000
# 25%    15364.000000  12028.000000  125140.000000  225077.000000     14.000000
# 50%    30819.000000  24330.000000  150032.000000  250007.000000     33.000000
# 75%    46475.000000  55083.000000  175117.000000  274727.000000     52.000000
# max    61532.000000  99999.000000  199993.000000  299999.000000     57.000000
#
#         LAST_WARDID           LOS
# count  13485.000000  13483.000000
# mean      32.778346      4.879872
# std       18.960811      9.462058
# min        7.000000      0.000600
# 25%       14.000000      1.109700
# 50%       33.000000      2.095600
# ...

# %%
print(icustays_df.isna().sum())
# Out:
# ROW_ID            0
# SUBJECT_ID        0
# HADM_ID           0
# ICUSTAY_ID        0
# DBSOURCE          0
# FIRST_CAREUNIT    0
# LAST_CAREUNIT     0
# FIRST_WARDID      0
# LAST_WARDID       0
# INTIME            0
# OUTTIME           2
# LOS               2
# dtype: int64

# %%
# INPUTEVENTS_CV_random.csv
inputevents_cv_csv = os.path.join(base_dir, "INPUTEVENTS_CV", "INPUTEVENTS_CV_random.csv")
inputevents_cv_df = pd.read_csv(inputevents_cv_csv)
inputevents_cv_df.head()
# Out:
# C:\Users\fsultana\AppData\Local\Temp\ipykernel_20008\316375319.py:3: DtypeWarning: Columns (7,9,17,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   inputevents_cv_df = pd.read_csv(inputevents_cv_csv)
#    ROW_ID  SUBJECT_ID   HADM_ID  ICUSTAY_ID            CHARTTIME  ITEMID  \
# 0     592       24457  184834.0    205776.0  2193-09-11 09:00:00   30056
# 1     593       24457  184834.0    205776.0  2193-09-11 12:00:00   30056
# 2     594       24457  184834.0    205776.0  2193-09-11 16:00:00   30056
# 3     595       24457  184834.0    205776.0  2193-09-11 19:00:00   30056
# 4     596       24457  184834.0    205776.0  2193-09-11 21:00:00   30056
#
#    AMOUNT AMOUNTUOM  RATE RATEUOM  ...  ORDERID  LINKORDERID  STOPPED  \
# 0   100.0        ml   NaN     NaN  ...   756654      9359133      NaN
# 1   200.0        ml   NaN     NaN  ...  3564075      9359133      NaN
# 2   160.0        ml   NaN     NaN  ...   422646      9359133      NaN
# ...

# %%
inputevents_cv_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6549232 entries, 0 to 6549231
# Data columns (total 22 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   ROW_ID             int64
#  1   SUBJECT_ID         int64
#  2   HADM_ID            float64
#  3   ICUSTAY_ID         float64
#  4   CHARTTIME          object
#  5   ITEMID             int64
#  6   AMOUNT             float64
#  7   AMOUNTUOM          object
#  8   RATE               float64
#  9   RATEUOM            object
#  10  STORETIME          object
#  11  CGID               float64
#  12  ORDERID            int64
#  13  LINKORDERID        int64
#  14  STOPPED            object
#  15  NEWBOTTLE          float64
#  16  ORIGINALAMOUNT     float64
#  17  ORIGINALAMOUNTUOM  object
#  18  ORIGINALROUTE      object
#  19  ORIGINALRATE       float64
#  20  ORIGINALRATEUOM    object
#  21  ORIGINALSITE       object
# dtypes: float64(8), int64(5), object(9)
# memory usage: 1.1+ GB

# %%
inputevents_cv_df.describe()
# Out:
#              ROW_ID    SUBJECT_ID       HADM_ID    ICUSTAY_ID        ITEMID  \
# count  6.549232e+06  6.549232e+06  6.540879e+06  6.538587e+06  6.549232e+06
# mean   8.757382e+06  1.580223e+04  1.504187e+05  2.510103e+05  3.016959e+04
# std    5.072400e+06  9.177731e+03  2.901622e+04  2.855434e+04  1.074803e+03
# min    1.000000e+00  1.200000e+01  1.000070e+05  2.000030e+05  3.000100e+04
# 25%    4.345837e+06  7.689000e+03  1.256060e+05  2.268270e+05  3.001800e+04
# 50%    8.730444e+06  1.591600e+04  1.497450e+05  2.524890e+05  3.006500e+04
# 75%    1.311652e+07  2.374500e+04  1.763070e+05  2.742940e+05  3.012800e+04
# max    1.752794e+07  3.281000e+04  1.999940e+05  2.999990e+05  4.679100e+04
#
#              AMOUNT          RATE          CGID       ORDERID   LINKORDERID  \
# count  4.643935e+06  1.533836e+06  6.422087e+06  6.549232e+06  6.549232e+06
# mean   7.424120e+01  1.114708e+02  1.776716e+04  6.004991e+06  5.976479e+06
# ...

# %%
print(inputevents_cv_df.isna().sum())
# Out:
# ROW_ID                     0
# SUBJECT_ID                 0
# HADM_ID                 8353
# ICUSTAY_ID             10645
# CHARTTIME                  0
# ITEMID                     0
# AMOUNT               1905297
# AMOUNTUOM            1608041
# RATE                 5015396
# RATEUOM              5000273
# STORETIME                  0
# CGID                  127145
# ORDERID                    0
# LINKORDERID                0
# STOPPED              6371522
# NEWBOTTLE            6458669
# ORIGINALAMOUNT       2828597
# ORIGINALAMOUNTUOM    1591205
# ORIGINALROUTE          42246
# ORIGINALRATE         4599310
# ORIGINALRATEUOM      4570608
# ORIGINALSITE         6489122
# dtype: int64

# %%
# INPUTEVENTS_MV_random.csv
inputevents_mv_csv = os.path.join(base_dir, "INPUTEVENTS_MV", "INPUTEVENTS_MV_random.csv")
inputevents_mv_df = pd.read_csv(inputevents_mv_csv)
inputevents_mv_df.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            STARTTIME  \
# 0     241       27063   139787    223259.0  2133-02-05 06:29:00
# 1     242       27063   139787    223259.0  2133-02-05 05:34:00
# 2     243       27063   139787    223259.0  2133-02-05 05:34:00
# 3     244       27063   139787    223259.0  2133-02-03 12:00:00
# 4     245       27063   139787    223259.0  2133-02-03 12:00:00
#
#                ENDTIME  ITEMID      AMOUNT AMOUNTUOM       RATE  ...  \
# 0  2133-02-05 08:45:00  225166    6.774532       mEq        NaN  ...
# 1  2133-02-05 06:30:00  225944   28.132997        ml  30.142497  ...
# 2  2133-02-05 06:30:00  225166    2.813300       mEq        NaN  ...
# 3  2133-02-03 12:01:00  225893    1.000000      dose        NaN  ...
# 4  2133-02-03 12:01:00  220949  100.000000        ml        NaN  ...
#
#   TOTALAMOUNTUOM ISOPENBAG  CONTINUEINNEXTDEPT  CANCELREASON  \
# 0             ml         0                   0             1
# ...

# %%
inputevents_mv_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2054331 entries, 0 to 2054330
# Data columns (total 31 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   ROW_ID                         int64
#  1   SUBJECT_ID                     int64
#  2   HADM_ID                        int64
#  3   ICUSTAY_ID                     float64
#  4   STARTTIME                      object
#  5   ENDTIME                        object
#  6   ITEMID                         int64
#  7   AMOUNT                         float64
#  8   AMOUNTUOM                      object
#  9   RATE                           float64
#  10  RATEUOM                        object
#  11  STORETIME                      object
#  12  CGID                           int64
#  13  ORDERID                        int64
#  14  LINKORDERID                    int64
#  15  ORDERCATEGORYNAME              object
#  16  SECONDARYORDERCATEGORYNAME     object
# ...

# %%
inputevents_mv_df.describe()
# Out:
#              ROW_ID    SUBJECT_ID       HADM_ID    ICUSTAY_ID        ITEMID  \
# count  2.054331e+06  2.054331e+06  2.054331e+06  2.054007e+06  2.054331e+06
# mean   1.799969e+06  6.366496e+04  1.503232e+05  2.498576e+05  2.242505e+05
# std    1.047347e+06  2.323415e+04  2.884606e+04  2.912425e+04  2.138252e+03
# min    1.860000e+02  2.300000e+01  1.000030e+05  2.000110e+05  2.208620e+05
# 25%    8.936385e+05  4.882100e+04  1.254790e+05  2.242970e+05  2.219060e+05
# 50%    1.796221e+06  6.583300e+04  1.508930e+05  2.505800e+05  2.251580e+05
# 75%    2.702674e+06  8.206500e+04  1.756270e+05  2.753880e+05  2.259420e+05
# max    3.618958e+06  9.999500e+04  1.999920e+05  2.999980e+05  2.283830e+05
#
#              AMOUNT          RATE          CGID       ORDERID   LINKORDERID  \
# count  2.054331e+06  1.164975e+06  2.054331e+06  2.054331e+06  2.054331e+06
# mean   2.226191e+02  9.268053e+01  1.752814e+04  5.001096e+06  5.005690e+06
# ...

# %%
print(inputevents_mv_df.isna().sum())
# Out:
# ROW_ID                                 0
# SUBJECT_ID                             0
# HADM_ID                                0
# ICUSTAY_ID                           324
# STARTTIME                              0
# ENDTIME                                0
# ITEMID                                 0
# AMOUNT                                 0
# AMOUNTUOM                              0
# RATE                              889356
# RATEUOM                           889356
# STORETIME                              0
# CGID                                   0
# ORDERID                                0
# LINKORDERID                            0
# ORDERCATEGORYNAME                      0
# SECONDARYORDERCATEGORYNAME        556174
# ORDERCOMPONENTTYPEDESCRIPTION          0
# ORDERCATEGORYDESCRIPTION               0
# PATIENTWEIGHT                          0
# TOTALAMOUNT                       300497
# TOTALAMOUNTUOM                    298384
# ISOPENBAG                              0
# ...
